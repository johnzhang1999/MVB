# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import random
import pathlib
import os
from generator import Generator
from keras.preprocessing.image import ImageDataGenerator
from skimage import exposure

tf.enable_eager_execution()
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
# def AHE(img):
#     img_adapteq = exposure.equalize_adapthist(img, clip_limit=0.03)
#     return img_adapteq
datagen = ImageDataGenerator(rotation_range=15,
                               width_shift_range=0.1,
                               height_shift_range=0.1,
                               shear_range=0.01,
                               zoom_range=[0.9, 1.25],
                               horizontal_flip=True,
                               vertical_flip=False,
                               fill_mode='nearest',
                               data_format='channels_last',
                               brightness_range=[0.5, 1.5])
#                                preprocessing_function=AHE)
test_gen = Generator(mode='test')
lib = test_gen.lib

# %%
def generate(id,imgs,t):
    print('generating:',t)
    for img in imgs:
        image = np.expand_dims(plt.imread(img), 0)
        if t == 'p':
            t = 'f'
        elif t =='g':
            t = 'b'
        save_path = '../aug_data/MVB_0505/test_500/' + id + '/' + t
        if not os.path.exists(save_path):
            os.makedirs(save_path)
        datagen.fit(image)
        for x, val in zip(datagen.flow(image, save_to_dir=save_path,save_prefix=id, save_format='jpg'),range(10*len(imgs))): 
            pass
    print('generated {} augs for {}'.format(10*len(imgs),id))

for i,(id,ps_and_gs) in enumerate(lib.items()):
    generate(id,ps_and_gs['probe'],'p')
    generate(id,ps_and_gs['gallery'],'g')
    print('#progress: {}/{}'.format(i,len(lib)))
# Out:
# generating: p
# generated 20 augs for f201804280024002128
# generating: g
# generated 30 augs for f201804280024002128
# #progress: 0/500
# generating: p
# generated 30 augs for f201804281310001973
# generating: g
# generated 30 augs for f201804281310001973
# #progress: 1/500
# generating: p
# generated 10 augs for f201804280124002326
# generating: g
# generated 30 augs for f201804280124002326
# #progress: 2/500
# generating: p
# generated 10 augs for f201804281917000660
# generating: g
# generated 30 augs for f201804281917000660
# #progress: 3/500
# generating: p
# generated 20 augs for f201804281345000409
# generating: g
# generated 30 augs for f201804281345000409
# #progress: 4/500
# generating: p
# generated 10 augs for f201804280257000122
# generating: g
# generated 30 augs for f201804280257000122
# #progress: 5/500
# generating: p
# generated 30 augs for f201804280638000066
# generating: g
# generated 10 augs for f201804280638000066
# #progress: 6/500
# generating: p
# ...
